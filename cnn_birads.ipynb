# %% [markdown]
# # Reconhecimento de Imagens com Redes Neurais Convolucionais

# %% [markdown]
# ## TÓPICOS EM COMPUTAÇÃO IV - DEEP LEARNING e VISÃO COMPUTACIONAL
#
# ### Pontifícia Universidade Católica de Minas Gerais
#
# #### Grupo:
# * Lauro Milagres Oliveira - 552140
# * Lucas Dutra Ponce Donoso de Leon - 553281

# %% [markdown]
# ## Introdução
#
# Problema:
#
# A densidade da mama é comprovadamente relacionada com o risco do desenvolvimento de câncer, uma vez que mulheres com uma maior densidade mamária podem esconder lesões, levando o câncer a ser detectado tardiamente. A escala de densidade chamada BI-RADS foi desenvolvida pelo American College of Radiology e informa os radiologistas sobre a diminuição da sensibilidade do exame com o aumento da densidade da mama. BI-RADS definem a densidade como sendo quase inteiramente composta por gordura (densidade I), por tecido fibrobroglandular difuso (densidade II), por tecido denso heterogêneo (III) e por tecido extremamente denso (IV). A mamografia é a principal ferramenta de rastreio do câncer e radiologistas avaliam a densidade da mama com base na análise visual das imagens.
#
# Objetivo:
#
# Neste trabalho, você deverá implementar uma rede neural convolucional que receba como entrada uma imagem com resolução de 128x128 pixels e 8 bits por pixel e possibilite o reconhecimento automáticoda densidade da mama.
#
# Solução: Usar uma Rede Neural Convolucional para aprender recursos de imagens e assim prever se uma imagem é do grupo 1, 2, 3 ou 4.

# %% [markdown]
# ## Definição dos Dados
#
# Total de imagens: 5024, 1.256 para cada classe.
#
# Conjunto de dados de treino: 70% das imagens de densidade BI-RADS.
#
# Conjunto de dados de validação: 70% das imagens de densidade BI-RADS.
#
# Conjunto de dados de teste: 30% do total de imagens ou imagem definida.

# %% [markdown]
# ## Fonte dos Dados
#
# Usaremos como fonte de dados o que foi disponibilizado pelo Professor ‪Alexei Manso Correa Machado‬.

# %% [markdown]
# ## Construindo a Rede Neural Convolucional
#
# Para a construção da rede neural, foi utilizado como backend o Keras e TensorFlow, o Keras utiliza o TensorFlow sendo uma biblioteca para simplificar muitos metodos e ajudando na contrução da rede neural.
#
# Segue abaixo os importes usados:

# %%
# Imports
import tensorflow as tf
import keras as K
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from IPython.display import Image
import numpy as np
from keras.preprocessing import image
import os
import random
import shutil

# %% [markdown]
# Nós então inicializamos a nossa rede:

# %%
# Inicializando a Rede Neural Convolucional
classifier = Sequential()

# %% [markdown]
# Agora nós definimos os parâmetros para o shape dos dados de entrada e a função de ativação. Usaremos 32 features para um array 2D e definiremos nosso array como o formato 3x3.
#
# Converteremos todas as nossas imagens 128x128 pixels em um array de 3 canais de cores.

# %%
# Passo 1 - Primeira Camada de Convolução
classifier.add(Conv2D(32, (1, 1),input_shape = (128, 128, 3), activation = 'relu'))

# %% [markdown]
# Agora aplicamos o agrupamento (pooling) para reduzir o tamanho do mapa de features resultado da primeira camada de convolução (dividido por 2):

# %%
# Passo 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %% [markdown]
# Adicionamos então a Segunda Camada de Convolução, tornando nossa rede um pouco mais profunda, e aplicando a camada de pooling à saída da camada de convolução anterior.

# %%
# Adicionando a Segunda Camada de Convolução
classifier.add(Conv2D(64, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %% [markdown]
# Adicionamos então a Segunda Camada de Convolução, tornando nossa rede um pouco mais profunda, e aplicando a camada de pooling à saída da camada de convolução anterior.

# %%
# Adicionando a Terceira Camada de Convolução
classifier.add(Conv2D(128, (1, 1), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %% [markdown]
# É aplicado o "achatamento" ou Flatten para converter a estrutura de dados 2D resultado da camada anterior em uma estrutura 1D, ou seja, um vetor.

# %%
# Passo 3 - Flattening
classifier.add(Flatten())

# %% [markdown]
# No próximo passo conectamos todas as camadas. Usamos uma função de ativação retificadora (relu) e então uma função de ativação sigmóide para obter as probabilidades de cada imagem conter as classes BI-RADS.

# %%
# Passo 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 4, activation = 'softmax')) #linear

# %% [markdown]
# Para compilar a rede, usamos o otimizador "Adam", um excelente algoritmo de primeira ordem para otimização baseada em gradiente de funções objetivas estocásticas, que toma como base uma estimativa adaptada de momentos de baixa ordem.
#
# Usamos uma função log loss com "entropia categorica cruzada", pois ela funciona bem com funções softmax.
#
# Nossa métrica será a acurácia, pois essa é nossa maior preocupação no treinamento deste tipo de modelo.

# %%
# Compilando a rede
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Treinando a Rede Neural Convolucional

# %% [markdown]
# ### Pré-Processamento

# %% [markdown]
# Realizando o pré-processamento nos dados para o treinamento usando a função ImageDataGenerator() do Keras e ajustar escala e zoom das imagens de treino e a escala das imagens de validação.

# %%
# Criando os objetos train_datagen e validation_datagen com as regras de pré-processamento das imagens
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
# train_datagen = ImageDataGenerator(rescale = 1./255)
validation_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# Aplicamos então os dois objetos criados anteriormente para pré-processar os dados de treino e de validação(que deve ser os mesmos de treino).
#
# Temos também neste bloco, os diretorios usado nesta rede neural, o de traino, validação e teste.

# %%
train_dir = '../Topicos/dataset_treino/'
valid_dir = '../Topicos/dataset_validation/'
teste_dir = '../Topicos/dataset_teste/'

'''
Funcao para prepaprar o diretorio, aqui fica definido a regra para divisao das imagens
Sao usados 4 diretorios, que são as classes BI-RADS, deste diretorio principal onde contem as 4 pastas,
são mantidas 70% das imagens e as outras 30% são jogadas em um diretorio de validação.
'''
def load_data(DIR):
    totalImages = 0
    for subDir in os.listdir(DIR):
        tam_dir_train = len(os.listdir(DIR+subDir))
        totalImages = totalImages + int(tam_dir_train*0.30)
        for i in range(int(tam_dir_train*0.30)):
            filename = random.choice(os.listdir(DIR+subDir))
            shutil.move(DIR+subDir+'/'+filename, teste_dir)
            # shutil.copy(DIR+subDir+'/'+filename, teste_dir)
    return int(totalImages/32)


steps_epoch = load_data(train_dir)
print(steps_epoch)

def create_validation_dataset(DIR):
    totalImages = 0
    for subDir in os.listdir(DIR):
        tam_dir_train = len(os.listdir(DIR+subDir))
        for filename in os.listdir(DIR+subDir):
            shutil.copy(DIR+subDir+'/'+filename, valid_dir)

create_validation_dataset(train_dir)

# Pré-processamento das imagens de treino e validação
training_set = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 shuffle=True,
                                                 classes= ['1', '2','3','4'],
                                                 class_mode = 'categorical')

validation_set = validation_datagen.flow_from_directory(valid_dir,
                                                        target_size = (128, 128),
                                                        batch_size = 32,
                                                        shuffle=True,
                                                        class_mode = 'categorical')
# Out:
# 47
# Found 3520 images belonging to 4 classes.
# Found 0 images belonging to 0 classes.

# %% [markdown]
# ### Treinamento

# %% [markdown]
# Usaremos passos definidos pelo total de imagens sobre batch size em nosso conjunto de treinamento para cada época. Escolhemos 2000 etapas de validação para as imagens de validação e 25 epocas.

# %%
# Executando o treinamento
classifier.fit(training_set,
                         steps_per_epoch = steps_epoch,
                         epochs = 25,
                         validation_data = validation_set,
                         validation_steps = 2000)

# Salvando o modelo
# classifier.save('../Topicos/model')
# Out:
# Epoch 1/25
# 47/47 [==============================] - 29s 627ms/step - loss: 1.5210 - accuracy: 0.2367
# Epoch 2/25
# 47/47 [==============================] - 37s 784ms/step - loss: 1.3849 - accuracy: 0.2540
# Epoch 3/25
# 47/47 [==============================] - 27s 570ms/step - loss: 1.3695 - accuracy: 0.2739
# Epoch 4/25
# 47/47 [==============================] - 24s 517ms/step - loss: 1.3040 - accuracy: 0.3730
# Epoch 5/25
# 47/47 [==============================] - 24s 521ms/step - loss: 1.2897 - accuracy: 0.3763
# Epoch 6/25
# 47/47 [==============================] - 25s 525ms/step - loss: 1.2335 - accuracy: 0.4156
# Epoch 7/25
# 47/47 [==============================] - 24s 516ms/step - loss: 1.2249 - accuracy: 0.4249
# Epoch 8/25
# 47/47 [==============================] - 26s 548ms/step - loss: 1.1937 - accuracy: 0.4335
# Epoch 9/25
# 47/47 [==============================] - 25s 529ms/step - loss: 1.2017 - accuracy: 0.4388
# Epoch 10/25
# 47/47 [==============================] - 25s 533ms/step - loss: 1.2152 - accuracy: 0.4302
# Epoch 11/25
# 47/47 [==============================] - 25s 524ms/step - loss: 1.2060 - accuracy: 0.4249
# Epoch 12/25
# 47/47 [==============================] - 24s 510ms/step - loss: 1.1912 - accuracy: 0.4328
# Epoch 13/25
# 47/47 [==============================] - 28s 591ms/step - loss: 1.1549 - accuracy: 0.4854
# Epoch 14/25
# 47/47 [==============================] - 27s 576ms/step - loss: 1.1367 - accuracy: 0.4947
# Epoch 15/25
# 47/47 [==============================] - 25s 536ms/step - loss: 1.1198 - accuracy: 0.4914
# Epoch 16/25
# 47/47 [==============================] - 25s 541ms/step - loss: 1.1152 - accuracy: 0.5140
# Epoch 17/25
# 47/47 [==============================] - 25s 531ms/step - loss: 1.0754 - accuracy: 0.5206
# Epoch 18/25
# 47/47 [==============================] - 29s 624ms/step - loss: 1.0427 - accuracy: 0.5665
# Epoch 19/25
# 47/47 [==============================] - 32s 689ms/step - loss: 1.0372 - accuracy: 0.5778
# Epoch 20/25
# 47/47 [==============================] - 29s 614ms/step - loss: 1.0300 - accuracy: 0.5525
# Epoch 21/25
# 47/47 [==============================] - 33s 696ms/step - loss: 1.0257 - accuracy: 0.5672
# Epoch 22/25
# 47/47 [==============================] - 40s 841ms/step - loss: 1.0161 - accuracy: 0.5426
# Epoch 23/25
# 47/47 [==============================] - 39s 837ms/step - loss: 1.0268 - accuracy: 0.5672
# Epoch 24/25
# 47/47 [==============================] - 41s 863ms/step - loss: 0.9866 - accuracy: 0.5924
# Epoch 25/25
# 47/47 [==============================] - 32s 690ms/step - loss: 0.9823 - accuracy: 0.5944

# %% [markdown]
# ## Previsões

# %% [markdown]
# Testando o modelo treinado com imagens que ele ainda não viu e que estão nos dados de teste.
#
# Para cada imagem de teste, é carregado as imagens com as mesmas dimensões usadas nas imagens de treino.
# Estas imagens por sua vez são convertidas em um array expandindo duas dimensões.

# %%
CLASSES = ["BIRADS 1","BIRADS 2","BIRADS 3","BIRADS 4"]

# imagem alearotoria
def getImagemAleatorio(DIR):
    return DIR+random.choice(os.listdir(DIR))

def isCorrect(arq,tipo):
    
    if "_d_" in arq and tipo == "BIRADS 1":
        return "ACERTOU"
    elif "_e_" in arq and tipo == "BIRADS 2":
        return "ACERTOU"
    elif "_f_" in arq and tipo == "BIRADS 3":
        return "ACERTOU"
    elif "_g_" in arq and tipo == "BIRADS 4":
        return "ACERTOU"
    else:
        return "ERROU"

def teste(DIR):
    listTeste = []
    print('==================================================================')
    for file in os.listdir(DIR):
        imagem = DIR+file
        print("Imagem: {}".format(file))
        # Image(filename='dataset_teste/'+file)
        test_image2 = image.load_img(imagem, target_size = (128, 128))
        input_arr = image.img_to_array(test_image2)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        pred = classifier.predict(input_arr/255)
        birads = np.argmax(pred)
        result = CLASSES[birads]
        
        acertoOuErro = isCorrect(file,result)
        listTeste.append(acertoOuErro)
        
        print("Densidade: {}".format(result))
        #print(acertoOuErro)
        print('==================================================================')
    
    print("Total de imagens de teste: {}".format(len(listTeste)))
    print("Acertou: {} ou {}%".format(listTeste.count('ACERTOU'),round(listTeste.count('ACERTOU')*100/len(listTeste),2)))
    print("Errou: {} ou {}%".format(listTeste.count('ERROU'),round(listTeste.count('ERROU')*100/len(listTeste),2)))

teste(teste_dir)
# Out:
# ==================================================================
# Imagem: p_d_right_mlo(119).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(163).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_mlo(214).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(153).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(69).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(235).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(217).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(47).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_cc(206).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(285).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(107).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(201).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(59).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(45).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(25).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(126).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(309).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(271).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(48).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(254).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(239).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(22).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(247).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(205).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(95).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(158).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(232).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(120).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_mlo(232).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_cc(69).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_cc(163).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(250).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_mlo(171).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(45).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(306).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(89).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(4).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(243).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(41).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_cc(78).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(108).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_mlo(237).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(20).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(248).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(221).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(27).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(239).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(262).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(225).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(115).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(52).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(207).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(138).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_mlo(55).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(69).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(307).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(141).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(217).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(74).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(37).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(127).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(302).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_cc(9).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(75).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(123).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(99).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(58).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(220).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(58).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(135).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(199).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(219).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(214).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(37).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(313).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(208).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(29).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(287).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(156).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(232).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(20).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(4).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(157).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(197).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(211).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_cc(307).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(283).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(48).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(60).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(205).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(253).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(124).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(99).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(73).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(211).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_mlo(123).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(246).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(51).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_mlo(267).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(85).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(126).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(137).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(94).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(8).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(189).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(147).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(240).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(303).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(154).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(129).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(128).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(60).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(248).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(236).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(284).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(50).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(112).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(18).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(201).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(52).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(314).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(36).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(96).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(90).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(243).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(220).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(296).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(128).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(206).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(75).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(3).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(19).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(131).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(256).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_mlo(224).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(262).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(198).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(244).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(167).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(133).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(249).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(138).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_mlo(37).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(74).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(128).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(129).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(113).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(209).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(89).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(41).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(12).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(146).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(287).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(264).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(186).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(182).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(260).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(122).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(6).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(11).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(270).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(231).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(132).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(145).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(4).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(67).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(69).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(16).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(208).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(288).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(20).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(191).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(254).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(114).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_cc(156).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(140).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(99).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(280).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(224).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(222).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(13).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(82).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(149).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_cc(309).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(134).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(229).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(236).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(171).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(168).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(286).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(180).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(32).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(265).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(51).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(227).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(113).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(21).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(125).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(223).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(287).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(102).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(218).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(194).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(100).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(190).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(64).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(164).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(24).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(10).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(79).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(203).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(202).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(164).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_mlo(287).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(53).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(184).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(29).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(184).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(280).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(190).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(169).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(297).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(5).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(247).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(245).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(34).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(312).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(102).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(166).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(174).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(81).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(239).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(276).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(23).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(262).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(121).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(11).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(8).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(222).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(123).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(55).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(111).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(307).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(241).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(106).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(217).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(64).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(183).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(210).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(236).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(36).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(165).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(197).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(185).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_mlo(42).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(52).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(22).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(218).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(190).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(274).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(226).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(111).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(50).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(86).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(290).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(260).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(68).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(109).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_mlo(129).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(92).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(269).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(68).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_mlo(181).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_cc(126).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(265).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_mlo(4).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(8).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(4).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(219).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(45).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(122).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_cc(70).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(10).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(61).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(62).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(289).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(252).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(50).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(112).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(158).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(230).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(120).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(216).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(140).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(14).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(312).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(190).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(230).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_cc(184).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(21).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(310).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(43).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(52).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(82).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_cc(122).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(152).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_cc(216).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(222).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(129).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(196).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_cc(298).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(81).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(274).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_mlo(87).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(137).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(124).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(160).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(252).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(45).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(29).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(238).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(273).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(179).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(46).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(298).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(76).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(225).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(274).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(206).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(120).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(34).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(163).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(159).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(231).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(11).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(138).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(154).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(34).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_cc(75).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(202).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(83).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(196).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(89).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(17).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(255).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_mlo(264).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_cc(117).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(95).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(183).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(306).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(21).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(88).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(229).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(40).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(52).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(183).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(168).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(159).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(311).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(53).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(113).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(237).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_cc(17).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(268).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(2).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(175).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(118).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(212).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(89).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(222).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(77).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_cc(202).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(181).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_mlo(265).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(31).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(25).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(134).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(190).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_cc(109).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(126).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_cc(116).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(244).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_cc(159).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_cc(148).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(239).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(295).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(245).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(124).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(157).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(64).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(232).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(137).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(140).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(182).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(162).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(266).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(95).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(172).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(220).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(41).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(110).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(36).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(84).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_mlo(63).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(161).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(48).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(255).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(246).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_mlo(193).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(74).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(80).png
# Densidade: BIRADS 4
# ==================================================================
# ...
# Imagem: p_e_right_cc(27).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(71).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(201).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(103).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(173).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(159).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(100).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_mlo(41).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(171).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(30).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(55).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(97).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(267).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(58).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(37).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_mlo(123).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(296).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(77).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(11).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_cc(23).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_cc(231).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(225).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(94).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_mlo(11).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(244).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(192).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(62).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(63).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_mlo(230).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(192).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(122).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_cc(148).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(42).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(132).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(63).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_mlo(302).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_left_cc(110).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_cc(246).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(111).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(154).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(198).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(261).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_cc(280).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(258).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(273).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(118).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(91).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(96).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(262).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(275).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(177).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(7).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(176).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_right_mlo(117).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_cc(110).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(168).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_cc(145).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(240).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(152).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(231).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_cc(284).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(110).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_cc(56).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(65).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_mlo(3).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(147).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(288).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(104).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_cc(12).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(273).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(110).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(46).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_cc(108).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_right_cc(194).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(242).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_mlo(229).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_left_mlo(51).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_d_right_mlo(295).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(85).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(185).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(175).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(303).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(292).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(151).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_right_mlo(63).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_right_cc(281).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_cc(14).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(287).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_left_mlo(144).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_right_mlo(49).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(45).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_d_right_mlo(301).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(249).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(50).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_right_cc(170).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_left_mlo(119).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(116).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(289).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(213).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(37).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_mlo(185).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(105).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_mlo(118).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_left_cc(179).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(256).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_cc(289).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_mlo(6).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(129).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_cc(309).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_f_right_mlo(244).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_cc(286).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_cc(191).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_e_left_mlo(269).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(9).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_left_mlo(36).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_mlo(39).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_left_cc(95).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_left_cc(168).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(301).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_mlo(139).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_g_right_cc(26).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_g_left_mlo(263).png
# Densidade: BIRADS 2
# ==================================================================
# Imagem: p_e_right_cc(264).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_cc(270).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_g_left_cc(27).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_f_right_mlo(138).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_right_cc(299).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_e_left_mlo(67).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_mlo(300).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_d_left_cc(183).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_g_left_mlo(154).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_left_cc(105).png
# Densidade: BIRADS 3
# ==================================================================
# Imagem: p_e_right_mlo(93).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_f_right_cc(181).png
# Densidade: BIRADS 4
# ==================================================================
# Imagem: p_d_right_mlo(91).png
# Densidade: BIRADS 1
# ==================================================================
# Imagem: p_f_left_cc(98).png
# Densidade: BIRADS 3
# ==================================================================
# Total de imagens de teste: 1504
# Acertou: 870 ou 57.85%
# Errou: 634 ou 42.15%

# %% [markdown]
# O modelo recebe uma imagem que nunca tinha visto antes e com base no que aprendeu durante o treinamento, foi capaz de classificar a imagem como sendo BI-RADS 1, 2, 3 ou 4!
#
# - O modelo treinado nada mais é do que um conjunto de pesos que foram definidos a partir de vetores de imagens de BI-RADS
# - Os pesos do modelo foram definidos com base nas características das imagens de treino
# - Convertemos a imagem de teste em um vetor de pixels e apresentamos ao modelo
# - O modelo compara o vetor da imagem de teste com seus pesos e então emite a classificação
#
# Abaixo, um bloco para rodar com o modelo salvo, ou com imagem definida.

# %%
# CLASSES = ["BIRADS 1","BIRADS 2","BIRADS 3","BIRADS 4"]

# loaded_model = tf.keras.models.load_model('../Topicos/model')

# print('##################################################################')
# print('#           Teste com modelo já treinado (Save in Disk)          #')
# print('##################################################################')

# for file in os.listdir(teste_dir):
#     imagem = teste_dir+file
#     print("Imagem: {}".format(imagem))
#     test_image2 = image.load_img(imagem, target_size = (128, 128))
#     input_arr = image.img_to_array(test_image2)
#     input_arr = np.array([input_arr])  # Convert single image to a batch.
#     pred = loaded_model.predict(input_arr/255)
#     birads = np.argmax(pred)
#     print(CLASSES[birads])


# print('##################################################################')
# print('#                       Teste com imagem                         #')
# print('##################################################################')
#imagem = 'dataset_teste/p_e_left_mlo(45).png'
# imagem = 'dataset_teste/alexei1.png'
#imagem = 'dataset_teste/alexei2.png'
# imagem = 'dataset_teste/alexei3.png'
# imagem = 'dataset_teste/alexei4.png'
# test_image = image.load_img(imagem, target_size = (128, 128))
# input_arr = image.img_to_array(test_image)
# input_arr = np.array([input_arr])  # Convert single image to a batch.
# pred = loaded_model.predict(input_arr/255)
# birads = np.argmax(pred)
# print(CLASSES[birads])
# Out:
# ##################################################################
# #                       Teste com imagem                         #
# ##################################################################
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe9a809d700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BIRADS 4

# %% [markdown]
# ## Conclusão
#
# Ao pesquisar na Internet, vimos que o recomendado para o kernel_size das imagens de entrada com 128x128 pixels seria um tamanho de 1 ou 3. Então optamos por começar com um kernel_size de tamanho 1, passamos para 3 no segundo layer para aprender recursos maiores e retornamos para 1 para reduzir as dimensões espaciais.
# Também vimos que era recomendado aumentar a quantidade de filtros nas camadas mais profundas. Assim,  as camadas iniciais na arquitetura de rede (ou seja, mais perto da imagem de entrada real) aprendem menos filtros convolucionais, enquanto as camadas mais profundas na rede (ou seja, mais próximas das previsões de saída) aprenderão mais filtros.
# O pool máximo é usado para reduzir as dimensões espaciais do volume de saída de cada camada.
